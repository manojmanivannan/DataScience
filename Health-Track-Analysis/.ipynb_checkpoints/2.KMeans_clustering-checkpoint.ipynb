\
# device_id
# 0003a6b8-e48b-11ea-8204-0242ac110002             9.325750  5171.495890
# 0007a88a-e48b-11ea-8204-0242ac110002            66.115919  7115.591781
# 000b9c56-e48b-11ea-8204-0242ac110002            84.725056  7257.693151
# 000f916c-e48b-11ea-8204-0242ac110002            68.119525  7129.690411
# 00176e5a-e48b-11ea-8204-0242ac110002             9.947677  5128.024658
#
#                                       steps_min  steps_max       lifestyle  \
# device_id
# 0003a6b8-e48b-11ea-8204-0242ac110002       2539       7837       Sedentary
# 0007a88a-e48b-11ea-8204-0242ac110002       3731      10189  Weight Trainer
# 000b9c56-e48b-11ea-8204-0242ac110002       4223      11156  Weight Trainer
# 000f916c-e48b-11ea-8204-0242ac110002       4413      10563  Weight Trainer
# 00176e5a-e48b-11ea-8204-0242ac110002       2938       7310       Sedentary
#
#                                       bmi_change
# device_id
# 0003a6b8-e48b-11ea-8204-0242ac110002    5.466266
# 0007a88a-e48b-11ea-8204-0242ac110002    5.298346
# 000b9c56-e48b-11ea-8204-0242ac110002    4.494924
# 000f916c-e48b-11ea-8204-0242ac110002    5.573329
# 00176e5a-e48b-11ea-8204-0242ac110002    7.437179

# %%
# we will use a subset of the columns 
interested_cols = ['resting_heartrate_avg', 'active_heartrate_avg', 'bmi_avg', 'vo2_avg', 'workout_minutes_avg', 'steps_max']
df_k = df[interested_cols]

# %%
distorsions = []
values_of_k = range(2,10)

# %%
for k in values_of_k:
    k_means = KMeans(n_clusters=k, random_state=42)
    k_means.fit(scale(df_k))
    distorsion = k_means.score(scale(df_k))
    distorsions.append(-distorsion)

# %%
plt.plot(values_of_k,distorsions, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Distorsions')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The Elbow (breaking point) seems to be around 4 or 5. This should be our optimum number of clusters

# %% [markdown]
# ### Splitting the data

# %%
train_df, inference_df = train_test_split(df_k, train_size=0.9, test_size=0.1, random_state=42)
train_df.shape
# Out:
# (2466, 6)

# %%
model = KMeans(n_clusters=4, random_state=42) 
model.fit(scale(train_df))
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
model.cluster_centers_
# Out:
# array([[-0.81944708, -0.83767397, -0.66461011,  0.83095443,  0.41536539,
#          0.86058361],
#        [ 1.46003975,  1.06970722,  0.02683551, -1.32987413,  0.34584581,
#         -1.00874487],
#        [-0.03852087,  0.17950084,  0.96576905, -0.09645165,  0.02954085,
#         -0.21871747],
#        [ 1.34537253,  1.43086145,  0.16019459, -1.22750788, -2.38211119,
#         -1.51559344]])

# %%
inference_df_clusters = model.predict(scale(inference_df))
inference_df['label'] = inference_df_clusters
# Out:
# <ipython-input-123-caf2d8d11502>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import plotly.express as px

pca = PCA(n_components=3)
components = pca.fit_transform(scale(inference_df))

total_var = pca.explained_variance_ratio_.sum() * 100

labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_3d(
    components, x=0, y=1, z=2, color=inference_df['label'],
    title=f'Total Explained Variance: {total_var:.2f}%',
    labels={'0': 'PC 1', '1': 'PC 2', '2': 'PC 3'}
)
fig.show()
# Out:
# <div>                            <div id="bb8694dc-2535-4c84-bfc5-4a656a3f81d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb8694dc-2535-4c84-bfc5-4a656a3f81d1")) {                    Plotly.newPlot(                        "bb8694dc-2535-4c84-bfc5-4a656a3f81d1",                        [{"hovertemplate": "PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<br>color=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [2, 2, 0, 0, 3, 3, 3, 3, 2, 0, 0, 2, 3, 0, 0, 1, 1, 0, 1, 0, 0, 0, 