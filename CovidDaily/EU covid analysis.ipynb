# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [18, 11]
# font = {'size'   : 22}

# plt.rc('font', **font)

# %%
df = pd.read_csv('data/eu_covid_daily.csv',parse_dates=['dateRep'])

# %%
df.head()
df.index = df.dateRep
df.drop('dateRep',axis=1,inplace=True)

# %%
df_2021=df.loc['2021-01-01':'2021-09-20']
# Out:
# <ipython-input-70-2e5ae5495415>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_2021=df.loc['2021-01-01':'2021-09-20']

# %%
death_country = df[['deaths','countriesAndTerritories']].groupby('countriesAndTerritories').sum().sort_values('deaths',ascending=True)

# %%
fig = plt.figure()
plt.barh(death_country.index,death_country['deaths'])
plt.xlabel('Deaths in year 2021 (January-September)')
plt.ylabel('Country')
plt.show()

# %%
df_italy = df.loc[df['countriesAndTerritories'] == 'Italy']

# %%
df_italy[['deaths']].loc[(df_italy['deaths'] <= 10000)].plot()
# Out:
# <AxesSubplot:xlabel='dateRep'>
